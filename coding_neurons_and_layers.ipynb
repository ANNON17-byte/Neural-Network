# %% [markdown]
# <a href="https://colab.research.google.com/github/ANNON17-byte/Neural-Network/blob/main/coding_neurons_and_layers.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3 - Input Neuron

# %%
inputs = [1, 2, 3]
weights = [0.2, 0.8, -0.5]
bias = 2  # bias is extra parameter added to weighed sum , which improve model learning and shift activation func

outputs = (inputs[0]*weights[0] + inputs[1]*weights[1] + inputs[2]*weights[2] + bias)

print(outputs)
# Out:
# 2.3

# %% [markdown]
# Layer

# %%
inputs = [1, 2, 3, 2.5]

weights = [[0.2, 0.8, -0.5, 1],
 [0.5, -0.91, 0.26, -0.5],
 [-0.26, -0.27, 0.17, 0.87]]

weights1 = weights[0]
weights2 = weights[1]
weights3 = weights[2]
biases = [2, 3, 0.5]

bias1 = 2
bias2 = 3
bias3 = 0.5

output = [
    inputs[0]*weights1[0] + inputs[1]*weights1[1] + inputs[2]*weights1[2] + inputs[3]*weights1[3] + bias1,
    inputs[0]*weights2[0] + inputs[1]*weights2[1] + inputs[2]*weights2[2] + inputs[3]*weights2[3] + bias2,
    inputs[0]*weights3[0] + inputs[1]*weights3[1] + inputs[2]*weights3[2] + inputs[3]*weights3[3] + bias3,
]

print(output)
# Out:
# [4.8, 1.21, 2.385]

# %% [markdown]
# Layer Using Loops

# %%
inputs = [1, 2, 3, 2.5]

weights = [[0.2, 0.8, -0.5, 1],
 [0.5, -0.91, 0.26, -0.5],
 [-0.26, -0.27, 0.17, 0.87]]

biases = [2, 3, 0.5]

output = []

#neuron_weight is single neuron weight
for neuron_weights, neuron_bias in zip(weights, biases):  #zip combines two list element by element
    neuron_output = 0
    for n_input, weight in zip(inputs, neuron_weights):
        neuron_output += n_input*weight
    neuron_output += neuron_bias # adding bias
    output.append(neuron_output)

print(output)
# Out:
# [4.8, 1.21, 2.385]

# %% [markdown]
# Single Neuron Using Numpy

# %%
inputs = [1.0, 2.0, 3.0, 2.5]
weights = [0.2, 0.8, -0.5, 1.0]
bias = 2.0

import numpy as np

#converting to array for dot product
input_array = np.array(inputs)
weight_array = np.array(weights)

output = np.dot(input_array, weight_array) + bias

print(output)
# Out:
# 4.8

# %% [markdown]
# Layers Of Neurons Using Numpy

# %%
inputs = [1.0, 2.0, 3.0, 2.5]
weights = [[0.2, 0.8, -0.5, 1],
           [0.5, -0.91, 0.26, -0.5],
           [-0.26, -0.27, 0.17, 0.87]]
biases = [2.0, 3.0, 0.5]

import numpy as np

inpuut_array = np.array(inputs)
weight_array = np.array(weights)
bias_array = np.array(biases)

output = np.dot(weight_array, inpuut_array) + bias_array

print(output)
# Out:
# [4.8   1.21  2.385]

# %% [markdown]
# Layer Of Neurons Case 2 (whenn inp matrix is 3*4 and output matrix is 3*4)

# %%
inputs = [[1.0, 2.0, 3.0, 2.5],
          [2.0, 5.0, -1.0, 2.0],
          [-1.5, 2.7, 3.3, -0.8]]
weights = [[0.2, 0.8, -0.5, 1],
           [0.5, -0.91, 0.26, -0.5],
           [-0.26, -0.27, 0.17, 0.87]]
biases = [2.0, 3.0, 0.5]

import numpy as np

inpuut_array = np.array(inputs)
weight_array = np.array(weights)
bias_array = np.array(biases)

output = np.dot(inpuut_array, weight_array.T) + bias_array

print(output)
# Out:
# [[ 4.8    1.21   2.385]
#  [ 8.9   -1.81   0.2  ]
#  [ 1.41   1.051  0.026]]

# %% [markdown]
# 2 Layers

# %%
inputs = [[1, 2, 3, 2.5],
          [2., 5., -1., 2],
          [-1.5, 2.7, 3.3, -0.8]]

weights = [[0.2, 0.8, -0.5, 1],
           [0.5, -0.91, 0.26, -0.5],
           [-0.26, -0.27, 0.17, 0.87]]

biases = [2, 3, 0.5]

weights2 = [[0.1, -0.14, 0.5],
            [-0.5, 0.12, -0.33],
            [-0.44, 0.73, -0.13]]

biases2 = [-1, 2, -0.5]

import numpy as np

inputs_array = np.array(inputs)
weights_array = np.array(weights)
biases_array = np.array(biases)
weights2_array = np.array(weights2)
biases2_array = np.array(biases2)

#first layer dot product

output1 = np.dot(inputs_array, weights_array.T) + biases_array

#second layer dot product

output2 = np.dot(output1, weights2_array.T) + biases2_array

print(output2)
# Out:
# [[ 0.5031  -1.04185 -2.03875]
#  [ 0.2434  -2.7332  -5.7633 ]
#  [-0.99314  1.41254 -0.35655]]

# %% [markdown]
# Generating Non Linear Training Data

# %%
# !pip install nnfs

# %%
from nnfs.datasets import spiral_data
import numpy as np
import nnfs
import matplotlib.pyplot as plt

nnfs.init()

# X = coordinates
# y = class label

X, y = spiral_data(samples =100,classes= 3)
plt.scatter(X[:,0], X[:,1])
plt.show()

# %%
plt.scatter( X[:,0], X[:,1] , c=y, cmap='brg')

# c= color, y= class labels
# brg = blue, red, green

plt.show()

# %% [markdown]
# Non-linear training data is needed because most real-world problems cannot be separated using a straight line. Linear models fail to capture complex patterns, while neural networks with non-linear activation functions can learn curved and complex decision boundaries.

# %% [markdown]
# Dense Layer Class

# %%
import nnfs
from nnfs.datasets import spiral_data
import numpy as np

nnfs.init()

class dense_layer:

  def __init__(self, inputs, neurons):
    #randomly assigning weights
    self.weights = 0.01 * np.random.randn(inputs, neurons)
    #1 row and neurons columns
    self.biases = np.zeros((1, neurons))

  def forward(self, inputs):
    self.output = np.dot(inputs, self.weights) + self.biases

#create dataset
X,y = spiral_data(samples=100, classes =3)

#create dense layer with 2 inputs and 3 output values
dense = dense_layer(2,3)
dense.forward(X)

#output of first 5 data
print(dense.output[:5])
# Out:
# [[ 0.0000000e+00  0.0000000e+00  0.0000000e+00]
#  [-1.0475188e-04  1.1395361e-04 -4.7983500e-05]
#  [-2.7414842e-04  3.1729150e-04 -8.6921798e-05]
#  [-4.2188365e-04  5.2666257e-04 -5.5912682e-05]
#  [-5.7707680e-04  7.1401405e-04 -8.9430439e-05]]

# %% [markdown]
# Activation Functions : Relu

# %% [markdown]
# ReLU introduces non-linear behavior, allowing networks to learn complex relationships

# %%
import numpy as np
inputs = [0, 2, -1, 3.3, -2.7, 1.1, 2.2, -100]
output = np.maximum(0, inputs)
print(output)

# %%
# ReLU activation class
class Activation_ReLU:
 # Forward pass
 def forward(self, inputs):
 # Calculate output values from input
  self.output = np.maximum(0, inputs)

# %% [markdown]
# Rectified Linear Unit
#
# Explanation
#
# Rectified → Negative values are removed (converted to 0)
#
# Linear → Positive values remain linear (unchanged)
#
# Unit → A single neuron operation

# %%
import nnfs
from nnfs.datasets import spiral_data
import numpy as np

X,y = spiral_data(samples = 100, classes = 3)

#2 inputs and 3 outputs
dense = dense_layer(2,3)

#relu activation layer
activation1 = Activation_ReLU()

#forward pass
dense.forward(X)

activation1.forward(dense.output)

print(activation1.output[:5])
# Out:
# [[0.         0.         0.        ]
#  [0.00137668 0.         0.        ]
#  [0.00221875 0.         0.        ]
#  [0.00407696 0.         0.        ]
#  [0.00545411 0.         0.        ]]

# %% [markdown]
# Softmax Activation Function : It converts a list of numbers into probabilities that sum to 1.

# %%
inputs = [[1, 2, 3, 2.5],
 [2., 5., -1., 2],
 [-1.5, 2.7, 3.3, -0.8]]

# Get unnormalized probabilities
exp_values = np.exp(inputs - np.max(inputs, axis=1,keepdims=True))
 # Normalize them for each sample
probabilities = exp_values / np.sum(exp_values, axis=1,keepdims=True)
print(probabilities)
np.sum(probabilities, axis = 1)
# Out:
# [[0.06414769 0.17437149 0.47399085 0.28748998]
#  [0.04517666 0.90739747 0.00224921 0.04517666]
#  [0.00522984 0.34875873 0.63547983 0.0105316 ]]
# array([1., 1., 1.])

# %%
# axis = 0 for row and axis = 1 for columns
# keepdims = true for correct broadcasting, alligning matrix dimensions

class Activation_Softmax:

  def forward(self,input):

    exp_values = np.exp(inputs - np.max(inputs, axis = 1 , keepdims= True))

    probabilities = exp_values / np.sum(exp_values, axis = 1 , keepdims = True)

    self.output = probabilities

# %%
from google.colab import files
files.upload()

# %%
from IPython.display import Image, display
display(Image("softmax.png"))

# %%
X,y = spiral_data(samples =100, classes =3)

dense1 = dense_layer(2,3)

activation1 = Activation_ReLU()

dense2 = dense_layer(3,3)

activation2 = Activation_Softmax()

dense1.forward(X)

activation1.forward(dense1.output)

dense2.forward(activation1.output)

activation2.forward(dense2.output)

print(activation2.output[:5])
# Out:
# [[0.06414769 0.17437149 0.47399085 0.28748998]
#  [0.04517666 0.90739747 0.00224921 0.04517666]
#  [0.00522984 0.34875873 0.63547983 0.0105316 ]]

# %%
from google.colab import files
files.upload()

# %%
from IPython.display import Image, display
display(Image("forward_pass.png"))

# %% [markdown]
# Categorical Cross Entropy Loss

# %%
from google.colab import files
files.upload()

# %%
from IPython.display import Image, display
display(Image("cross_entropy_loss.png"))
